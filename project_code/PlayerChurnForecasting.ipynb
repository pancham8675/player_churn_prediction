# %%
pip install google-colab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 9.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls /content/drive/MyDrive
# Out:
# '12th marksheet.pdf'
#  1632649426092.jpg
#  1632928177757.jpg
#  1F3A9204.JPG
# '20000 MIT fees sem 6.pdf'
#  2Y8A0345.JPG
#  75c9c61d-b95a-4523-9cc6-c1ca4a245947.mp4
#  Adhaar.pdf
# 'AIML Lab Manual.gdoc'
#  Architecture.drawio
# 'Churn Project Architecture (1).drawio.png'
# 'Churn Project Architecture.drawio'
# 'Churn Project Architecture.drawio.png'
# 'Churn Project Configuration options diagram.drawio'
#  Class10Marksheet.pdf
#  Class12LeavingCertificate.pdf
#  Classroom/
# 'Colleges visited & Group Members .gsheet'
# 'Copy of Research Paper.gdoc'
# 'Copy of Unit II.gslides'
# 'DAA Unit 1 (1).gdoc'
# 'DAA Unit 1.gdoc'
# 'Data Analytics project ideas.gsheet'
#  DFormA.pdf
#  DomicileCertificatePanchamBandishti.pdf
# 'DS Assignment 1 - 5 2213627.pdf'
# 'Dual Stack Pancham Bandishti 2213627 CNL PA2.pkt'
# 'experiment list.gdoc'
# 'Fee Reciept sem 5 60000.pdf'
# "FRESHER'S PARTY 2022 LIST.gsheet"
# 'FY STUDENT MENTORSHIP FORM 21-22.pdf'
#  Image.jpg
#  IMG-20190517-WA0034.jpg
# ...

# %%
drive.mount('MP4')

# %%
import pandas as pd

# %%
df=pd.read_csv('/dataset.csv',header = 0,encoding = 'utf-8')
df.head()
# Out:
#    Player ID  Level  Attempts  Time Played  Booster Used Guild Active  \
# 0       1241     20         5        34000             0           No
# 1       1301    100        20        29000             2           No
# 2       1312    500       100        14000            10           No
# 3       1453     20         5        41000             0           No
# 4       2411    150        30        30000             3           No
#
#   Daily Login  Last Purchase Amount Last Purchase Date  Gifts Sent  ...  \
# 0         Yes                   0.0                NaN           0  ...
# 1         Yes                   0.0                NaN           4  ...
# 2         Yes                   0.0                NaN          20  ...
# 3         Yes                   0.0                NaN           0  ...
# 4         Yes                   0.0                NaN           6  ...
#
#    OS Version  Purchase Type  Achievements Completed  Stuck Level (duration)  \
# ...

# %%
df.shape
# Out:
# (1053, 28)

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b666bf274d0a> in <cell line: 1>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined
